# %%
#default_exp audio.model
#default_cls_lvl 3

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#export
from local.core import *
from local.torch_basics import *
from local.test import *
from local.data.all import *
from local.optimizer import *
from local.metrics import *
from local.vision.learner import *
from local.audio.core import *
from local.notebook.showdoc import *

# %%
import zipfile

# %%
from zipfile import ZipFile

# %%
url = "https://github.com/karoldvl/ESC-50/archive/master.zip"

# %%
zipfile.open()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-adee237be4e2> in <module>
# ----> 1 zipfile.open()
#
# AttributeError: module 'zipfile' has no attribute 'open'

# %%
def zip_extract(fname, dest):
    zipfile.ZipFile(fname, mode='r').extractall(dest)

# %%
path = untar_data(url, extract_func=zip_extract)

# %%
path
# Out:
# PosixPath('/home/kbird/.fastai/data/master')

# %%
path = Path.home()/".fastai/data/ESC-50-master/audio"

# %%
path
# Out:
# PosixPath('/home/kbird/.fastai/data/ESC-50-master/audio')

# %%
items = get_audio_files(path)

# %%
split_idx = RandomSplitter()(items)

# %%
mel_args = {'sample_rate': 44100, 'n_fft': 2560}

# %%
pipe_audio = Pipeline([AudioSignal.create, MelSpectrogramify(**mel_args), AmplitudeToDBify()], as_item=True)

# %%
pipe_audio(items[0])
# Out:
# tensor([[[ 19.9262,  26.1792,  19.7233,  ...,  19.1721,  16.3122,  19.5270],
#          [ 18.0439,  20.4803,  20.5529,  ...,  20.8349,  16.7609,  14.2495],
#          [ 21.0154,  23.5795,  24.0690,  ...,  18.2519,  17.7518,  19.2528],
#          ...,
#          [-38.8462, -55.6684, -56.3198,  ..., -56.8876, -40.8654, -32.1484],
#          [-34.2004, -56.0750, -54.6879,  ..., -56.7633, -55.7205, -32.6729],
#          [-34.6933, -54.0305, -55.2806,  ..., -56.8744, -55.4135, -32.9107]]])

# %%
def labeller(o, **kwargs):
    return labels[labels.filename==o.name]["category"].values[0]

# %%
labels = pd.read_csv(Path.home()/".fastai/data/ESC-50-master/meta/esc50.csv")

# %%
labels
# Out:
#                filename  fold  target        category  esc10  src_file take
# 0      1-100032-A-0.wav     1       0             dog   True    100032    A
# 1     1-100038-A-14.wav     1      14  chirping_birds  False    100038    A
# 2     1-100210-A-36.wav     1      36  vacuum_cleaner  False    100210    A
# 3     1-100210-B-36.wav     1      36  vacuum_cleaner  False    100210    B
# 4     1-101296-A-19.wav     1      19    thunderstorm  False    101296    A
# ...                 ...   ...     ...             ...    ...       ...  ...
# 1995   5-263831-B-6.wav     5       6             hen  False    263831    B
# 1996  5-263902-A-36.wav     5      36  vacuum_cleaner  False    263902    A
# 1997   5-51149-A-25.wav     5      25       footsteps  False     51149    A
# 1998    5-61635-A-8.wav     5       8           sheep  False     61635    A
# 1999     5-9032-A-0.wav     5       0             dog   True      9032    A
#
# [2000 rows x 7 columns]

# %%
class PetAudioTfm(Transform):
    def __init__(self, items, train_idx):
        self.items,self.train_idx = items,train_idx
        self.labeller = labeller
        vals = map(self.labeller, items[train_idx])
        self.vocab,self.o2i = uniqueify(vals, sort=True, bidir=True)

    def encodes(self, i):
        o = self.items[i]
        return pipe_audio(o), self.o2i[self.labeller(o)]
    
    def decodes(self, x): return TitledImage(x[0],self.vocab[x[1]])

# %%
pets = DataBlock(types=(AudioSpectrogram, Category), 
          get_items=get_audio_files, 
          splitter=RandomSplitter(), 
          get_y=labeller
         )

# %%
dbunch = pets.databunch(path, item_tfms=pipe_audio, bs=4)

# %%
dbunch.show_batch()

# %%
from torch.nn import Conv2d, Sequential, Module

# %%
from torchvision.models import resnet34

# %%
opt_func = partial(Adam, lr=3e-3, wd=0.01)

# %%
learn = cnn_learner(dbunch, resnet34, opt_func=opt_func, metrics=[accuracy, error_rate], path=Path("~/.fastai"))

# %%
learn.model[0][0].in_channels=1

# %%
learn.model[0][0].weight = torch.nn.parameter.Parameter(learn.model[0][0].weight[:,1,:,:].unsqueeze(1))

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.628607</td>
#       <td>4.719117</td>
#       <td>0.105000</td>
#       <td>0.895000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.027500</td>
#       <td>0.972500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.027500</td>
#       <td>0.972500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.027500</td>
#       <td>0.972500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.027500</td>
#       <td>0.972500</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, 2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.275184</td>
#       <td>1.802344</td>
#       <td>0.457500</td>
#       <td>0.542500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.255978</td>
#       <td>1.604450</td>
#       <td>0.565000</td>
#       <td>0.435000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.997015</td>
#       <td>1.402605</td>
#       <td>0.595000</td>
#       <td>0.405000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.825710</td>
#       <td>1.293424</td>
#       <td>0.627500</td>
#       <td>0.372500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.740333</td>
#       <td>1.372040</td>
#       <td>0.597500</td>
#       <td>0.402500</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.761897</td>
#       <td>4.300833</td>
#       <td>0.090000</td>
#       <td>0.910000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.432916</td>
#       <td>499688306376704.000000</td>
#       <td>0.080000</td>
#       <td>0.920000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.257029</td>
#       <td>83.153595</td>
#       <td>0.090000</td>
#       <td>0.910000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.764623</td>
#       <td>5.047360</td>
#       <td>0.225000</td>
#       <td>0.775000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.246228</td>
#       <td>11.332150</td>
#       <td>0.267500</td>
#       <td>0.732500</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(50, 2e-2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='50', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.00% [11/50 02:03<07:17]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.156911</td>
#       <td>7.596677</td>
#       <td>0.245000</td>
#       <td>0.755000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.088593</td>
#       <td>27.476013</td>
#       <td>0.275000</td>
#       <td>0.725000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.137743</td>
#       <td>4.603323</td>
#       <td>0.280000</td>
#       <td>0.720000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.083713</td>
#       <td>24.870760</td>
#       <td>0.262500</td>
#       <td>0.737500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.096110</td>
#       <td>38314712.000000</td>
#       <td>0.282500</td>
#       <td>0.717500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.137695</td>
#       <td>12.585833</td>
#       <td>0.197500</td>
#       <td>0.802500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.333131</td>
#       <td>16.486256</td>
#       <td>0.237500</td>
#       <td>0.762500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.591937</td>
#       <td>37.545929</td>
#       <td>0.172500</td>
#       <td>0.827500</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.977010</td>
#       <td>16.844172</td>
#       <td>0.175000</td>
#       <td>0.825000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.201114</td>
#       <td>9.145920</td>
#       <td>0.105000</td>
#       <td>0.895000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.266904</td>
#       <td>67.608337</td>
#       <td>0.052500</td>
#       <td>0.947500</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='169' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       42.25% [169/400 00:04<00:06 5.9570]
#     </div>

# %%
preds, targs = learn.get_preds()

# %%
preds.argmax(dim=1)
# Out:
# tensor([24,  3, 11, 31, 39, 23, 41, 22, 24, 12, 33,  8, 24, 44, 16, 42, 17,  8,
#         23, 33, 26, 11,  0,  0, 39, 38,  1, 43, 24, 38, 16, 23, 36, 22,  2, 39,
#         12, 13, 15, 22, 23, 36, 21, 46,  0,  2, 41,  3,  5, 11, 15, 41, 11, 48,
#         11, 13,  9, 14, 43,  1, 43,  5, 43, 24, 32, 11, 26, 36, 17, 21,  0, 23,
#         16, 47, 31, 16,  6,  1, 45,  3, 23, 19, 10, 43, 11,  8, 24,  0, 39, 11,
#          8, 26, 27, 28, 19, 15, 27,  4, 24, 46, 45, 45, 16,  5,  0, 23,  9, 31,
#         49,  7, 22,  7, 23, 44,  9, 49, 48, 16, 20, 45,  1, 38, 46,  9, 27, 34,
#         30, 15, 11, 17, 11, 23, 39, 33, 40, 37, 43, 43,  8, 43, 33, 30, 19, 10,
#          2, 31, 25, 43, 41,  1, 24, 36, 20, 23, 20, 39, 32, 34, 25, 46,  6,  3,
#         22, 13, 42, 38,  4, 33, 18, 39, 33, 43,  5, 19, 31,  8, 36, 43,  6, 35,
#         24, 39, 18, 19,  2,  0, 32, 27, 40,  6, 23, 21, 42, 16,  4, 42, 11, 36,
#         35, 32, 24, 24, 34, 44, 16, 46, 41, 26, 19,  1, 36, 11, 22, 23, 15, 36,
#         38,  7, 22,  2, 46, 39, 14, 13, 24, 27, 48, 17, 46, 30,  3, 25, 27, 40,
#          4, 27,  8,  1,  8,  3, 15, 39, 11, 11, 28, 41, 37, 23, 26,  1, 45, 46,
#         21, 46, 41, 32, 24, 36, 10,  1, 42,  2, 23, 24, 36, 42, 32, 23, 23, 38,
#         11, 43,  9, 19,  4, 18, 15, 39, 47, 14, 31,  2, 21, 42, 35, 17, 49, 41,
#         39, 26, 17, 40, 42, 15,  3, 30,  8, 15, 10, 27, 11, 12, 25,  3, 10, 47,
#         24, 23,  1, 14, 15,  8, 22, 15, 15, 45, 11,  6,  8, 41,  3,  9, 45, 22,
#         15, 22,  7,  6, 11, 38, 47, 39, 39, 11, 15,  1, 33, 21,  6,  6, 42, 40,
#         15, 42, 14, 23, 16, 19, 20,  2, 24,  4, 41,  2, 22, 22, 26, 15, 15, 20,
#         30, 14,  0, 14,  0, 21, 24,  9,  6, 49, 16, 21,  9,  4, 25, 28, 16,  1,
#         43, 49, 21, 18,  0, 24, 22, 22, 44, 19, 18, 24, 32, 23, 16, 30,  0,  5,
#         14, 41, 16, 13])

# %%
targs
# Out:
# tensor([47,  3, 11, 33,  5, 23, 41, 28, 24, 41, 33,  4, 21, 44, 37, 47, 17,  8,
#         20, 33, 26, 11, 28,  0, 17, 38,  1, 43, 24, 38, 16, 48, 22, 22,  2, 13,
#         29, 13, 28, 28, 11, 36, 41, 46, 45,  2, 18, 31,  5,  3, 15,  5, 11, 35,
#         33, 13,  9, 14, 43, 10, 43, 37, 42, 24, 29, 24, 26, 36, 17, 41, 45, 20,
#          1, 47, 31, 16,  3, 13, 34,  3, 20, 19, 10, 43, 11, 40,  3,  0, 16, 31,
#          8, 12, 27, 22,  5, 15, 27,  4, 24, 47, 45, 45, 15,  5,  4, 23,  9, 11,
#         49,  7, 45, 29, 19, 44, 27, 45, 32, 16, 20, 47,  1, 38, 46, 18, 27, 34,
#         30,  7, 33, 17, 29, 23, 39, 33, 40, 37, 43, 43,  8, 45,  3, 30, 32, 10,
#         35, 31, 25, 49, 21,  6, 24, 36, 20, 23, 20, 39, 29, 34, 25, 46,  6, 33,
#          4, 30, 16, 38,  5, 33, 18, 32, 48, 49,  5, 19, 31,  8, 36, 43,  6, 35,
#          9, 13, 18, 32,  2,  0, 32, 27, 40,  6, 23, 41, 42, 16,  4, 42, 11, 36,
#         35, 29, 45, 34, 34, 44, 37, 46,  3,  4, 10,  1, 36, 11, 47, 23, 25, 36,
#         43,  7, 22,  2, 46, 39,  2, 13, 27, 27, 48, 17, 49, 30, 35, 25, 44, 40,
#          4, 27,  8,  1,  8, 33,  7, 17, 11, 14, 28, 18, 37, 18, 26,  1, 21, 46,
#         41, 46, 41, 29, 26, 36, 34, 19, 42,  2, 24, 24, 36, 42, 32, 34, 23, 47,
#         11, 43, 24, 29, 29, 18,  7, 16, 46, 14, 31,  2, 21, 42, 35, 17, 45, 41,
#         39, 48, 17, 40, 42, 15, 41, 30,  8, 15, 32, 27, 18, 12,  7,  3, 10, 47,
#         45, 26, 41,  2, 15,  8, 28,  7, 15, 45, 33, 13,  8, 41, 41,  9, 45, 47,
#         15, 22,  7,  6,  9, 38, 47,  5, 39, 11,  7, 34, 33, 41,  6,  6, 42,  4,
#         15, 42, 14, 43, 37, 26, 24, 35, 31,  4, 41,  2, 22,  2, 26,  7, 15, 20,
#         30,  2,  0, 14,  0, 21, 23,  9,  6,  0, 16, 41, 44,  4, 25, 28, 16, 17,
#         43, 49, 42, 18, 45, 24, 22, 22, 44, 19, 18, 24, 35, 21, 16, 30, 49, 19,
#         14, 48, 16, 13])

# %%
learn.dbunch.valid_ds[-1].show

# %%
AudioSignal.create(learn.dbunch.valid_ds[-1][0]).show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
